# %% [markdown]
# Importazione Librerie per pre-processing

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# Importazione dataset tweet

# %%
df = pd.read_json('ManchesterCity.json', lines=True)
df.head(15)
# Out:
#                 user_id  ...          created_at
# 0   1005383795049160704  ... 2021-08-15 14:55:02
# 1              21232426  ... 2021-08-15 14:55:03
# 2             312030415  ... 2021-08-15 14:55:03
# 3             250247877  ... 2021-08-15 14:55:06
# 4             612287510  ... 2021-08-15 14:55:11
# 5   1314149979506855936  ... 2021-08-15 14:55:13
# 6   1398473665939902466  ... 2021-08-15 14:55:13
# 7             326843156  ... 2021-08-15 14:55:14
# 8   1286740682292572162  ... 2021-08-15 14:55:16
# 9             992931882  ... 2021-08-15 14:55:16
# 10  1302656358299426827  ... 2021-08-15 14:55:18
# 11  1154482853595557890  ... 2021-08-15 14:55:18
# 12  1321434943474540547  ... 2021-08-15 14:55:21
# 13           2222352885  ... 2021-08-15 14:55:21
# 14  1365442592003997699  ... 2021-08-15 14:55:23
#
# [15 rows x 11 columns]

# %% [markdown]
# Check sui type del dataset

# %%
df.dtypes
# Out:
# user_id                   int64
# username                 object
# screen_name              object
# text                     object
# full_text                object
# hashtags                 object
# retweeted                  bool
# retweet_count             int64
# favorite                  int64
# followers                 int64
# created_at       datetime64[ns]
# dtype: object

# %% [markdown]
# Il type degli attributi è corretto tranne per user_id, si provvede a correggerlo

# %%
df["user_id"] = df["user_id"].astype(str, copy = False)
df.dtypes
# Out:
# user_id                  object
# username                 object
# screen_name              object
# text                     object
# full_text                object
# hashtags                 object
# retweeted                  bool
# retweet_count             int64
# favorite                  int64
# followers                 int64
# created_at       datetime64[ns]
# dtype: object

# %% [markdown]
# Check su presenza retweet o favorite

# %%
check_rt = df[df['retweeted'] == True]
len(check_rt)
# Out:
# 0

# %%
check_fv = df[df['favorite'] == 1]
len(check_fv)
# Out:
# 0

# %%
check_rtc = df[df['retweet_count'] > 0]
len(check_rtc)
# Out:
# 0

# %% [markdown]
# Non sono presenti retweet o favorite
#
# Si eliminano i campi non rilevanti e si riordinano gli attributi

# %%
df = df.drop(['retweet_count', 'favorite', 'retweeted'], axis = 1)
df.head(15)
# Out:
#                 user_id  ...          created_at
# 0   1005383795049160704  ... 2021-08-15 14:55:02
# 1              21232426  ... 2021-08-15 14:55:03
# 2             312030415  ... 2021-08-15 14:55:03
# 3             250247877  ... 2021-08-15 14:55:06
# 4             612287510  ... 2021-08-15 14:55:11
# 5   1314149979506855936  ... 2021-08-15 14:55:13
# 6   1398473665939902466  ... 2021-08-15 14:55:13
# 7             326843156  ... 2021-08-15 14:55:14
# 8   1286740682292572162  ... 2021-08-15 14:55:16
# 9             992931882  ... 2021-08-15 14:55:16
# 10  1302656358299426827  ... 2021-08-15 14:55:18
# 11  1154482853595557890  ... 2021-08-15 14:55:18
# 12  1321434943474540547  ... 2021-08-15 14:55:21
# 13           2222352885  ... 2021-08-15 14:55:21
# 14  1365442592003997699  ... 2021-08-15 14:55:23
#
# [15 rows x 8 columns]

# %%
df = df[['created_at', 'user_id',	'username',	'screen_name',	'text',	'full_text',	'hashtags',	'followers']]
df.head(15)
# Out:
#             created_at              user_id  ...              hashtags followers
# 0  2021-08-15 14:55:02  1005383795049160704  ...              [TOTMCI]       285
# 1  2021-08-15 14:55:03             21232426  ...  [Tottenham, ManCity]      6075
# 2  2021-08-15 14:55:03            312030415  ...                    []        71
# 3  2021-08-15 14:55:06            250247877  ...                    []       463
# 4  2021-08-15 14:55:11            612287510  ...                    []     11468
# 5  2021-08-15 14:55:13  1314149979506855936  ...             [ManCity]       109
# 6  2021-08-15 14:55:13  1398473665939902466  ...                    []        41
# 7  2021-08-15 14:55:14            326843156  ...                    []       629
# 8  2021-08-15 14:55:16  1286740682292572162  ...                    []        84
# 9  2021-08-15 14:55:16            992931882  ...             [ManCity]       656
# 10 2021-08-15 14:55:18  1302656358299426827  ...                    []       353
# 11 2021-08-15 14:55:18  1154482853595557890  ...             [ManCity]      1103
# 12 2021-08-15 14:55:21  1321434943474540547  ...                    []      3040
# 13 2021-08-15 14:55:21           2222352885  ...                    []       117
# 14 2021-08-15 14:55:23  1365442592003997699  ...                    []       293
#
# [15 rows x 8 columns]

# %% [markdown]
# Si crea una nuova colonna per il testo che consideri il full text dove presente e il text in caso contrario

# %%
def text(row):
  if len(row['full_text']) > len(row['text']):
    return row['full_text']   
  else:
    return row['text']

# %%
df['text_clean'] = df.apply(text, axis=1)
df.head(15)
# Out:
#             created_at  ...                                         text_clean
# 0  2021-08-15 14:55:02  ...  ⚽ 888Sport Double Bargain ⚽\n\n⚪ Tottenham @ 3...
# 1  2021-08-15 14:55:03  ...  How many goals will be scored in #Tottenham vs...
# 2  2021-08-15 14:55:03  ...  RT @David_Ornstein: 🚨 Tottenham striker Harry ...
# 3  2021-08-15 14:55:06  ...  RT @SimonBrundish: £550m starting lineup, the ...
# 4  2021-08-15 14:55:11  ...  De Bruyne asked to sit the bench because he ca...
# 5  2021-08-15 14:55:13  ...  RT @City_Xtra: Official: #ManCity Starting XI ...
# 6  2021-08-15 14:55:13  ...  RT @city_tactics: Sterling goes straight in. L...
# 7  2021-08-15 14:55:14  ...  RT @Stillberto: This guy has played a lot of g...
# 8  2021-08-15 14:55:16  ...                                   LFG C’mon Citeh!
# 9  2021-08-15 14:55:16  ...  RT @City_Xtra: Harry Kane will not be in Totte...
# 10 2021-08-15 14:55:18  ...                             RT @sayo_Xz: Go boys ⚡
# 11 2021-08-15 14:55:18  ...  RT @ManCity: Back and ready to do it all again...
# 12 2021-08-15 14:55:21  ...      This team is good man https://t.co/923dxPAHGm
# 13 2021-08-15 14:55:21  ...  @angelucci94 @Jonocardoso main event city!!! h...
# 14 2021-08-15 14:55:23  ...  RT @mcfcjude: Torres, Mendy, Ake and 70 year o...
#
# [15 rows x 9 columns]

# %% [markdown]
# Si opera adesso sugli hashtag, si recuperano gli hashtag presenti nel testo

# %%
def hashtags(row):
  compi1 = re.compile('(#[Mm]an[Cc]ity)')
  compi2 = re.compile('(#[Mm]anchester[Cc]ity[Ff]c)')
  compi3 = re.compile('(#[Mm]anchester[Cc]ity)')
  compi4 = re.compile('(#[Mm][Cc][Ff][Cc])')
  compi5 = re.compile('(#[Pp]remier[Ll]eague)')
  compi6 = re.compile('(#[Pp][Ll])')
  compi7 = re.compile('(#[Tt]ottenham)')
  compi8 = re.compile('(#[Ss]purs)')
  compi9 = re.compile('(#[Cc][Oo][Yy][Ss])')
  compi10 = re.compile('(#[Tt][Hh][Ff][Cc])')
  compi11 = re.compile('(#TOTMCI)')

  hast = []
  
  subs1 = compi1.search(row['text_clean'])
  subs2 = compi2.search(row['text_clean'])
  subs3 = compi3.search(row['text_clean'])
  subs4 = compi4.search(row['text_clean'])
  subs5 = compi5.search(row['text_clean'])
  subs6 = compi6.search(row['text_clean'])
  subs7 = compi7.search(row['text_clean'])
  subs8 = compi8.search(row['text_clean'])
  subs9 = compi9.search(row['text_clean'])
  subs10 = compi10.search(row['text_clean'])
  subs11 = compi11.search(row['text_clean'])

  if subs1:
    if subs1.group(1) not in df['hashtags']: 
      hast.append(subs1.group(1).strip('#'))
  if subs2:
    if subs2.group(1) not in df['hashtags']:
      hast.append(subs2.group(1).strip('#'))
  if subs3:
    if subs3.group(1) not in df['hashtags']:
      hast.append(subs3.group(1).strip('#'))
  if subs4:
    if subs4.group(1) not in df['hashtags']:
      hast.append(subs4.group(1).strip('#'))
  if subs5:   
    if subs5.group(1) not in df['hashtags']:
      hast.append(subs5.group(1).strip('#'))
  if subs6:
    if subs6.group(1) not in df['hashtags']:
      hast.append(subs6.group(1).strip('#'))
  if subs7:
    if subs7.group(1) not in df['hashtags']:
      hast.append(subs7.group(1).strip('#'))
  if subs8:
    if subs8.group(1) not in df['hashtags']:
      hast.append(subs8.group(1).strip('#'))
  if subs9:   
    if subs9.group(1) not in df['hashtags']:
      hast.append(subs9.group(1).strip('#'))
  if subs10:
    if subs10.group(1) not in df['hashtags']:
      hast.append(subs10.group(1).strip('#'))
  if subs11:
    if subs11.group(1) not in df['hashtags']:
      hast.append(subs11.group(1).strip('#'))           
  return hast

# %%
df['has']=df.apply(hashtags, axis=1)

# %% [markdown]
# Si concatenano gli hashtag ottenuti dallo streaming e dal testo ed eliminando i duplicati si hanno tutti gli hashtag presenti nel tweet

# %%
df['hashtag_fin'] = df['hashtags'] + df['has']

# %%
def hashtag_puliti(row):
  np.array(row['hashtag_fin'])
  fi= np.unique(row['hashtag_fin'])
  return fi

# %%
df['compl_hashtags'] = df.apply(hashtag_puliti, axis=1)
df.head(15)
# Out:
#             created_at  ...                                     compl_hashtags
# 0  2021-08-15 14:55:02  ...  [COYS, MCFC, ManCity, PremierLeague, Spurs, TH...
# 1  2021-08-15 14:55:03  ...  [COYS, MCFC, ManCity, PremierLeague, Spurs, TH...
# 2  2021-08-15 14:55:03  ...                                                 []
# 3  2021-08-15 14:55:06  ...                                                 []
# 4  2021-08-15 14:55:11  ...                                                 []
# 5  2021-08-15 14:55:13  ...                                          [ManCity]
# 6  2021-08-15 14:55:13  ...                                                 []
# 7  2021-08-15 14:55:14  ...                                                 []
# 8  2021-08-15 14:55:16  ...                                                 []
# 9  2021-08-15 14:55:16  ...                                          [ManCity]
# 10 2021-08-15 14:55:18  ...                                                 []
# 11 2021-08-15 14:55:18  ...                                          [ManCity]
# 12 2021-08-15 14:55:21  ...                                                 []
# 13 2021-08-15 14:55:21  ...                                                 []
# 14 2021-08-15 14:55:23  ...                                                 []
#
# [15 rows x 12 columns]

# %% [markdown]
# Si assume nel tentativo di attribuire l'appartenenza ad una tifoseria che sia necessaria la presenza di hashtag all'elaborazione

# %%
def selezione(row):
  lung = len(row['compl_hashtags'])
  if lung != 0:
    return 'Yes'
  else:
    return 'No'

# %%
df['Keep'] = df.apply(selezione, axis =1)
df_clean = df[df['Keep'] == "Yes"]
df_clean.head(15)
# Out:
#             created_at  ... Keep
# 0  2021-08-15 14:55:02  ...  Yes
# 1  2021-08-15 14:55:03  ...  Yes
# 5  2021-08-15 14:55:13  ...  Yes
# 9  2021-08-15 14:55:16  ...  Yes
# 11 2021-08-15 14:55:18  ...  Yes
# 15 2021-08-15 14:55:26  ...  Yes
# 19 2021-08-15 14:55:40  ...  Yes
# 20 2021-08-15 14:55:42  ...  Yes
# 22 2021-08-15 14:55:46  ...  Yes
# 24 2021-08-15 14:55:56  ...  Yes
# 25 2021-08-15 14:55:56  ...  Yes
# 26 2021-08-15 14:55:59  ...  Yes
# 27 2021-08-15 14:56:01  ...  Yes
# 31 2021-08-15 14:56:09  ...  Yes
# 34 2021-08-15 14:56:10  ...  Yes
#
# [15 rows x 13 columns]

# %% [markdown]
# Si tratta adesso la variabile tempo (created_at)
#
# Si importa la libreria necessaria a trattare date e orari

# %%
from datetime import *

# %% [markdown]
# Abbiamo inziato lo streaming dei tweet circa alle 16:55, si nota pertanto che nel dataset l'orario di creazione del tweet è riportato con due ore di differenza, presumibilmente dovute al fuso orario. Con la seguente funzione si compensa questo valore per riportarsi all'orario italiano.

# %%
def time(loc_date_time):
    date_time = loc_date_time + timedelta(hours = 2)
    return date_time 

df_clean['time'] = df_clean['created_at'].apply(time)

df_clean.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#             created_at              user_id  ... Keep                time
# 0  2021-08-15 14:55:02  1005383795049160704  ...  Yes 2021-08-15 16:55:02
# 1  2021-08-15 14:55:03             21232426  ...  Yes 2021-08-15 16:55:03
# 5  2021-08-15 14:55:13  1314149979506855936  ...  Yes 2021-08-15 16:55:13
# 9  2021-08-15 14:55:16            992931882  ...  Yes 2021-08-15 16:55:16
# 11 2021-08-15 14:55:18  1154482853595557890  ...  Yes 2021-08-15 16:55:18
# 15 2021-08-15 14:55:26             40153977  ...  Yes 2021-08-15 16:55:26
# 19 2021-08-15 14:55:40            921690248  ...  Yes 2021-08-15 16:55:40
# 20 2021-08-15 14:55:42            382677125  ...  Yes 2021-08-15 16:55:42
# 22 2021-08-15 14:55:46   714327341334331392  ...  Yes 2021-08-15 16:55:46
# 24 2021-08-15 14:55:56  1242460757398368256  ...  Yes 2021-08-15 16:55:56
# 25 2021-08-15 14:55:56  1070854955437907969  ...  Yes 2021-08-15 16:55:56
# 26 2021-08-15 14:55:59  1326158447440769027  ...  Yes 2021-08-15 16:55:59
# 27 2021-08-15 14:56:01  1372049400126599168  ...  Yes 2021-08-15 16:56:01
# 31 2021-08-15 14:56:09            208709219  ...  Yes 2021-08-15 16:56:09
# 34 2021-08-15 14:56:10  1019358185579139072  ...  Yes 2021-08-15 16:56:10
#
# [15 rows x 14 columns]

# %% [markdown]
# Dovendo far riferimento al minuto della partita si è ritenuto opportuno riportarsi ad una situazione di tempo discretizzato a 15 secondi.

# %%
time_time = pd.concat([pd.Series(df_clean["time"].dt.hour),
                       pd.Series(df_clean["time"].dt.minute),
                       pd.Series(df_clean["time"].dt.second)],axis=1)

# %%
time_time["hour"] = time_time.iloc[:,0]
time_time["minute"] = time_time.iloc[:,1]
time_time["second"] = time_time.iloc[:,2]

# %%
time_time["second"] = time_time["second"]/15
time_time["second"] = time_time["second"].round()
time_time["second"] = time_time["second"]*15

# %%
time_time.loc[time_time["second"] == 60.0,"minute"] = time_time["minute"] + 1
time_time.loc[time_time["second"] == 60.0,"second"] = time_time["second"] -60
time_time.loc[time_time["minute"] == 60.0,"hour"] = time_time["hour"] + 1
time_time.loc[time_time["minute"] == 60.0,"minute"] = time_time["minute"] -60
time_time.loc[time_time["second"] == 0.0,"second"] = "00"
time_time.loc[time_time["second"] == 15.0,"second"] = "15"
time_time.loc[time_time["second"] == 30.0,"second"] = "30"
time_time.loc[time_time["second"] == 45.0,"second"] = "45"

# %%
time_time["hour"] = time_time["hour"].apply(lambda x: str(x))
time_time["minute"] = time_time["minute"].apply(lambda x: str(x))
time_time["second"] = time_time["second"].apply(lambda x: str(x))

# %%
time_time = pd.Series("2021/08/15 " + time_time["hour"] + ":" + time_time["minute"] + ":" + time_time["second"])
time_time = time_time.apply(lambda x: str(x)).copy()

# %%
def converttime(dstring):
    return datetime.strptime(dstring, "%Y/%m/%d %H:%M:%S")

# %%
time_time = time_time.apply(lambda x: converttime(x)).copy() #non so togliere warning copy
df_clean["disc_time"] = time_time
df_clean.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             created_at  ...           disc_time
# 0  2021-08-15 14:55:02  ... 2021-08-15 16:55:00
# 1  2021-08-15 14:55:03  ... 2021-08-15 16:55:00
# 5  2021-08-15 14:55:13  ... 2021-08-15 16:55:15
# 9  2021-08-15 14:55:16  ... 2021-08-15 16:55:15
# 11 2021-08-15 14:55:18  ... 2021-08-15 16:55:15
# 15 2021-08-15 14:55:26  ... 2021-08-15 16:55:30
# 19 2021-08-15 14:55:40  ... 2021-08-15 16:55:45
# 20 2021-08-15 14:55:42  ... 2021-08-15 16:55:45
# 22 2021-08-15 14:55:46  ... 2021-08-15 16:55:45
# 24 2021-08-15 14:55:56  ... 2021-08-15 16:56:00
# 25 2021-08-15 14:55:56  ... 2021-08-15 16:56:00
# 26 2021-08-15 14:55:59  ... 2021-08-15 16:56:00
# 27 2021-08-15 14:56:01  ... 2021-08-15 16:56:00
# 31 2021-08-15 14:56:09  ... 2021-08-15 16:56:15
# 34 2021-08-15 14:56:10  ... 2021-08-15 16:56:15
#
# [15 rows x 15 columns]

# %% [markdown]
# Va riportato adesso l'orario al riferimento temporale nella partita ovvero il minuto del match.
#
# La partita è iniziata puntualmente alle 17:30, sono stati concessi 2 minuti di recupero nel primo tempo e 6 nel secondo. L'intervallo è durato regolarmente circa 15 minuti. Si ipotizza, inoltre, un compenso di circa un minuto tra evento della partita e pubblicazione del tweet. La durata dell'evento incluso l'intervallo è stata di 113 minuti.
#
# Si fa una prima discrimanzione tra tweet pubblicati durante o a ridosso della partita e gli altri.

# %%
def minute_from_start(loc_date_time):
    
    date_time = loc_date_time - timedelta(hours = 17, minutes = 31)
    
    if date_time.day == 14: # escludo pre-partita
        minute = np.nan
    
    elif date_time.hour == 0:
        minute = date_time.minute
         
    else: 
        minute =  date_time.minute + date_time.hour*60
        
    return minute

# %%
df_clean['minute_from_start'] = df_clean['disc_time'].apply(minute_from_start)
df_clean.tail(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                created_at  ... minute_from_start
# 11579 2021-08-15 18:30:14  ...             179.0
# 11582 2021-08-15 18:30:24  ...             179.0
# 11585 2021-08-15 18:30:38  ...             179.0
# 11586 2021-08-15 18:30:41  ...             179.0
# 11587 2021-08-15 18:30:41  ...             179.0
# 11589 2021-08-15 18:30:41  ...             179.0
# 11590 2021-08-15 18:30:41  ...             179.0
# 11592 2021-08-15 18:30:41  ...             179.0
# 11593 2021-08-15 18:30:42  ...             179.0
# 11594 2021-08-15 18:30:42  ...             179.0
# 11596 2021-08-15 18:30:43  ...             179.0
# 11599 2021-08-15 18:30:52  ...             179.0
# 11602 2021-08-15 18:30:53  ...             180.0
# 11603 2021-08-15 18:30:54  ...             180.0
# 11605 2021-08-15 18:30:55  ...             180.0
#
# [15 rows x 16 columns]

# %% [markdown]
# Suddivido i tweet in Pre-partita, Intervallo, Primo Tempo, Secondo Tempo e Post-Partita

# %%
def pre_partita(minute):
  try:
      if np.isnan(minute) == True:
        moment = "Pre"
      else:
        moment = "Other"
  except:
    moment = "Other"
  return moment

# %%
df_clean['Moment'] = df_clean['minute_from_start'].apply(pre_partita)
df_clean.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             created_at              user_id  ... minute_from_start Moment
# 0  2021-08-15 14:55:02  1005383795049160704  ...               NaN    Pre
# 1  2021-08-15 14:55:03             21232426  ...               NaN    Pre
# 5  2021-08-15 14:55:13  1314149979506855936  ...               NaN    Pre
# 9  2021-08-15 14:55:16            992931882  ...               NaN    Pre
# 11 2021-08-15 14:55:18  1154482853595557890  ...               NaN    Pre
# 15 2021-08-15 14:55:26             40153977  ...               NaN    Pre
# 19 2021-08-15 14:55:40            921690248  ...               NaN    Pre
# 20 2021-08-15 14:55:42            382677125  ...               NaN    Pre
# 22 2021-08-15 14:55:46   714327341334331392  ...               NaN    Pre
# 24 2021-08-15 14:55:56  1242460757398368256  ...               NaN    Pre
# 25 2021-08-15 14:55:56  1070854955437907969  ...               NaN    Pre
# 26 2021-08-15 14:55:59  1326158447440769027  ...               NaN    Pre
# 27 2021-08-15 14:56:01  1372049400126599168  ...               NaN    Pre
# 31 2021-08-15 14:56:09            208709219  ...               NaN    Pre
# 34 2021-08-15 14:56:10  1019358185579139072  ...               NaN    Pre
#
# [15 rows x 17 columns]

# %%
pre_match = df_clean[df_clean["Moment"] == "Pre"].copy()
match_post = df_clean[df_clean["Moment"] == "Other"].copy()
match_post.head(15)
# Out:
#               created_at              user_id  ... minute_from_start Moment
# 2101 2021-08-15 15:30:53   837362634005454848  ...               0.0  Other
# 2102 2021-08-15 15:30:53             38991991  ...               0.0  Other
# 2103 2021-08-15 15:30:53            518715968  ...               0.0  Other
# 2104 2021-08-15 15:30:54  1261979991224565760  ...               0.0  Other
# 2105 2021-08-15 15:30:54           2177947717  ...               0.0  Other
# 2106 2021-08-15 15:30:54             52102899  ...               0.0  Other
# 2107 2021-08-15 15:30:54            110366369  ...               0.0  Other
# 2109 2021-08-15 15:30:54           1291586280  ...               0.0  Other
# 2110 2021-08-15 15:30:55   733686121968881664  ...               0.0  Other
# 2111 2021-08-15 15:30:55            518715968  ...               0.0  Other
# 2112 2021-08-15 15:30:56  1216651467895058432  ...               0.0  Other
# 2113 2021-08-15 15:30:58  1347892685814771712  ...               0.0  Other
# 2114 2021-08-15 15:30:58            919149067  ...               0.0  Other
# 2115 2021-08-15 15:30:58           2360551094  ...               0.0  Other
# 2116 2021-08-15 15:31:00  1391670619737976833  ...               0.0  Other
#
# [15 rows x 17 columns]

# %%
len(pre_match) + len(match_post) == len(df_clean)
# Out:
# True

# %%
def momento(minute):
  if minute <= 46:
    moment = "Primo"
  elif minute > 112:
    moment = "Post"  
  elif (minute > 46) & (minute <= 61):
    moment = "Intervallo"
  else:
    moment = "Secondo"
  
  return moment

# %%
match_post['Moment'] = match_post['minute_from_start'].apply(momento)
match_post.head(15)
# Out:
#               created_at              user_id  ... minute_from_start Moment
# 2101 2021-08-15 15:30:53   837362634005454848  ...               0.0  Primo
# 2102 2021-08-15 15:30:53             38991991  ...               0.0  Primo
# 2103 2021-08-15 15:30:53            518715968  ...               0.0  Primo
# 2104 2021-08-15 15:30:54  1261979991224565760  ...               0.0  Primo
# 2105 2021-08-15 15:30:54           2177947717  ...               0.0  Primo
# 2106 2021-08-15 15:30:54             52102899  ...               0.0  Primo
# 2107 2021-08-15 15:30:54            110366369  ...               0.0  Primo
# 2109 2021-08-15 15:30:54           1291586280  ...               0.0  Primo
# 2110 2021-08-15 15:30:55   733686121968881664  ...               0.0  Primo
# 2111 2021-08-15 15:30:55            518715968  ...               0.0  Primo
# 2112 2021-08-15 15:30:56  1216651467895058432  ...               0.0  Primo
# 2113 2021-08-15 15:30:58  1347892685814771712  ...               0.0  Primo
# 2114 2021-08-15 15:30:58            919149067  ...               0.0  Primo
# 2115 2021-08-15 15:30:58           2360551094  ...               0.0  Primo
# 2116 2021-08-15 15:31:00  1391670619737976833  ...               0.0  Primo
#
# [15 rows x 17 columns]

# %%
df_time = pd.concat([match_post, pre_match], ignore_index=True).copy()
df_time
# Out:
#               created_at              user_id  ... minute_from_start Moment
# 0    2021-08-15 15:30:53   837362634005454848  ...               0.0  Primo
# 1    2021-08-15 15:30:53             38991991  ...               0.0  Primo
# 2    2021-08-15 15:30:53            518715968  ...               0.0  Primo
# 3    2021-08-15 15:30:54  1261979991224565760  ...               0.0  Primo
# 4    2021-08-15 15:30:54           2177947717  ...               0.0  Primo
# ...                  ...                  ...  ...               ...    ...
# 8419 2021-08-15 15:30:51            544160781  ...               NaN    Pre
# 8420 2021-08-15 15:30:51  1413844469082955781  ...               NaN    Pre
# 8421 2021-08-15 15:30:51           1176640496  ...               NaN    Pre
# 8422 2021-08-15 15:30:52  1402802214893064193  ...               NaN    Pre
# 8423 2021-08-15 15:30:52             26348382  ...               NaN    Pre
#
# [8424 rows x 17 columns]

# %% [markdown]
# Va costruita una funzione che attribuisca il minuto all'interno della partita.

# %%
def match_minute(row):
  st_minute = row['minute_from_start']
  moment = row['Moment']
  
  if moment == "Secondo":
    minuto = st_minute - 17 + 1
  
  elif moment == "Primo":
    minuto = st_minute + 1
  
  else:
    minuto = np.nan
  
  return minuto

# %%
df_time['Minute'] = df_time.apply(match_minute, axis = 1)
df_time[df_time['Minute'] == 47]
# Out:
#               created_at              user_id  ...   Moment Minute
# 1666 2021-08-15 16:16:53  1400477496844369927  ...    Primo   47.0
# 1667 2021-08-15 16:16:53   807998293678534656  ...    Primo   47.0
# 1668 2021-08-15 16:16:53  1331582016039526401  ...    Primo   47.0
# 1669 2021-08-15 16:16:55            998270383  ...    Primo   47.0
# 1670 2021-08-15 16:16:55  1318567411164041216  ...    Primo   47.0
# ...                  ...                  ...  ...      ...    ...
# 2408 2021-08-15 16:34:35            621877524  ...  Secondo   47.0
# 2409 2021-08-15 16:34:35  1366763323094614023  ...  Secondo   47.0
# 2410 2021-08-15 16:34:43  1309257539889049602  ...  Secondo   47.0
# 2411 2021-08-15 16:34:43            185588456  ...  Secondo   47.0
# 2412 2021-08-15 16:34:46  1225002789329408001  ...  Secondo   47.0
#
# [117 rows x 18 columns]

# %% [markdown]
# Con la seguente funzione si gestisce la questione minuti di recupero creando riferimenti univoci per il minuto della partita nel dataset.

# %%
def minute_str(row):
  
  minute = row['Minute']
  moment = row['Moment']
  
  if moment == "Primo":
    if minute <= 45:
      min = str(int(minute))
    else:
      rec = int(minute - 45)
      min = "45+"+str(rec)
  
  elif moment == "Secondo":
    if minute <= 90:
      min = str(int(minute))
    else:
      rec = int(minute - 90)
      min = "90+"+str(rec)
  
  else:
    min = np.nan
  
  return min

# %%
df_time['Min_Cronaca'] = df_time.apply(minute_str, axis = 1)
df_time
# Out:
#               created_at              user_id  ... Minute Min_Cronaca
# 0    2021-08-15 15:30:53   837362634005454848  ...    1.0           1
# 1    2021-08-15 15:30:53             38991991  ...    1.0           1
# 2    2021-08-15 15:30:53            518715968  ...    1.0           1
# 3    2021-08-15 15:30:54  1261979991224565760  ...    1.0           1
# 4    2021-08-15 15:30:54           2177947717  ...    1.0           1
# ...                  ...                  ...  ...    ...         ...
# 8419 2021-08-15 15:30:51            544160781  ...    NaN         NaN
# 8420 2021-08-15 15:30:51  1413844469082955781  ...    NaN         NaN
# 8421 2021-08-15 15:30:51           1176640496  ...    NaN         NaN
# 8422 2021-08-15 15:30:52  1402802214893064193  ...    NaN         NaN
# 8423 2021-08-15 15:30:52             26348382  ...    NaN         NaN
#
# [8424 rows x 19 columns]

# %%
df_time[df_time["Min_Cronaca"] == "45+2"]
# Out:
#               created_at              user_id  ... Minute Min_Cronaca
# 1666 2021-08-15 16:16:53  1400477496844369927  ...   47.0        45+2
# 1667 2021-08-15 16:16:53   807998293678534656  ...   47.0        45+2
# 1668 2021-08-15 16:16:53  1331582016039526401  ...   47.0        45+2
# 1669 2021-08-15 16:16:55            998270383  ...   47.0        45+2
# 1670 2021-08-15 16:16:55  1318567411164041216  ...   47.0        45+2
# ...                  ...                  ...  ...    ...         ...
# 1756 2021-08-15 16:17:50  1382258906836168708  ...   47.0        45+2
# 1757 2021-08-15 16:17:50            208045361  ...   47.0        45+2
# 1758 2021-08-15 16:17:52           1277649421  ...   47.0        45+2
# 1759 2021-08-15 16:17:52            192323475  ...   47.0        45+2
# 1760 2021-08-15 16:17:52  1402639836876402694  ...   47.0        45+2
#
# [95 rows x 19 columns]

# %%
df_T_clean = df_time.drop(['Minute', 'created_at', 'Keep', 'hashtag_fin','has', 'text', 'full_text', 'username', 'disc_time'], axis = 1)
df_T_clean
# Out:
#                   user_id      screen_name  ... Moment  Min_Cronaca
# 0      837362634005454848          nayupoy  ...  Primo            1
# 1                38991991   iMustPandaLean  ...  Primo            1
# 2               518715968  NBCSportsSoccer  ...  Primo            1
# 3     1261979991224565760       cityscoop_  ...  Primo            1
# 4              2177947717         WaiiYuee  ...  Primo            1
# ...                   ...              ...  ...    ...          ...
# 8419            544160781     frizzyfazzel  ...    Pre          NaN
# 8420  1413844469082955781       donuthaver  ...    Pre          NaN
# 8421           1176640496   SteveStevens47  ...    Pre          NaN
# 8422  1402802214893064193        Ojie_ajeh  ...    Pre          NaN
# 8423             26348382           ryr12r  ...    Pre          NaN
#
# [8424 rows x 10 columns]

# %% [markdown]
# Si procede ad attribuire l'appartenenza ad una tifoseria basandosi sugli hashtag citati e sulla relativa sentiment analysis.
#
# Di seguito l'importazione delle librerie necessarie.

# %%
import nltk
from nltk.stem import PorterStemmer
from gensim.parsing.preprocessing import remove_stopwords
import string
# !pip3 install vaderSentiment
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 7.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %% [markdown]
# Applichiamo una pulizia del testo per migliorare l'efficacia della sentiment analysis.

# %%
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub(r"RT","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub(r":","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub("@\w*","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub("#\w*","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub("\n","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(str)
df_T_clean["text_clean"] = df_T_clean["text_clean"].str.lower()
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: re.sub(r"\d+", "",text))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: text.translate(str.maketrans('', '', string.punctuation)))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: remove_stopwords(text))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: re.sub(r"'", "",text))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: re.sub(r"https\w*", "",text))

# %% [markdown]
# Attribuzione degli score per la sentiment analysis.

# %%
sid = SentimentIntensityAnalyzer()
df_T_clean['scores'] = df_T_clean['text_clean'].apply(lambda review: sid.polarity_scores(review))
df_T_clean['compound']  = df_T_clean['scores'].apply(lambda score_dict: score_dict['compound'])
df_T_clean.head(15)
# Out:
#                 user_id  ... compound
# 0    837362634005454848  ...   0.0000
# 1              38991991  ...   0.5859
# 2             518715968  ...   0.3400
# 3   1261979991224565760  ...   0.0000
# 4            2177947717  ...   0.4215
# 5              52102899  ...   0.0000
# 6             110366369  ...   0.0000
# 7            1291586280  ...   0.4215
# 8    733686121968881664  ...   0.3400
# 9             518715968  ...   0.0000
# 10  1216651467895058432  ...  -0.9698
# 11  1347892685814771712  ...   0.3400
# 12            919149067  ...   0.4215
# 13           2360551094  ...   0.3400
# 14  1391670619737976833  ...   0.4215
#
# [15 rows x 12 columns]

# %% [markdown]
# Viene attribuito ad ogni tweet una label circa il sentiment del tweet sulla base dello score ottenuto.

# %%
def comp_score(compund):
  if compund >=0.05:
    return 'Positive'
  elif compund <= -0.05:
    return 'Negative'
  else:
    return 'Neutral'

# %%
df_T_clean['comp_score'] = df_T_clean['compound'].apply(comp_score)
df_T_clean.head(15)
# Out:
#                 user_id      screen_name  ... compound  comp_score
# 0    837362634005454848          nayupoy  ...   0.0000     Neutral
# 1              38991991   iMustPandaLean  ...   0.5859    Positive
# 2             518715968  NBCSportsSoccer  ...   0.3400    Positive
# 3   1261979991224565760       cityscoop_  ...   0.0000     Neutral
# 4            2177947717         WaiiYuee  ...   0.4215    Positive
# 5              52102899           D_Lusk  ...   0.0000     Neutral
# 6             110366369   hustla4sho_213  ...   0.0000     Neutral
# 7            1291586280      _BhekumuziG  ...   0.4215    Positive
# 8    733686121968881664           __sugy  ...   0.3400    Positive
# 9             518715968  NBCSportsSoccer  ...   0.0000     Neutral
# 10  1216651467895058432     EfiaOkorewaa  ...  -0.9698    Negative
# 11  1347892685814771712          PeguyDj  ...   0.3400    Positive
# 12            919149067         ZurFaies  ...   0.4215    Positive
# 13           2360551094       cashthib68  ...   0.3400    Positive
# 14  1391670619737976833         kobe__38  ...   0.4215    Positive
#
# [15 rows x 13 columns]

# %% [markdown]
# Si crea una funzione che attribuisce la supposta appartenenza del tweet ad una tifoseria basandosi sugli hashtag citati e sulla neutralità o meno del tweet.

# %%
def tifoso(row):
  compound = row['compound'] 
  riga = row['compl_hashtags']
  if  ([row['comp_score'] =='Neutral']) and (('ManCity' in riga) or ('ManchesterCity' in riga)  or ('mcfc' in riga) or ('MCFC' in riga)) and (('PremierLeague' in riga) or ('pl' in riga) or ('PL' in riga) or ('TOTMCI' in riga)) and (('COYS' in riga) or ('thfc' in riga) or ('THFC' in riga) or ('spurs' in riga) or ('Spurs' in riga) or ('Tottenham' in riga)):
    if (compound>=-0.05 ) & (compound<=0.05):
      return "Neutral"
    else:
      return 'Manchester City'
  else:
    return 'Manchester City'

# %%
df_T_clean['tifo'] = df_T_clean.apply(tifoso, axis=1)
df_T_clean.head(15)
# Out:
#                 user_id      screen_name  ... comp_score             tifo
# 0    837362634005454848          nayupoy  ...    Neutral          Neutral
# 1              38991991   iMustPandaLean  ...   Positive  Manchester City
# 2             518715968  NBCSportsSoccer  ...   Positive  Manchester City
# 3   1261979991224565760       cityscoop_  ...    Neutral  Manchester City
# 4            2177947717         WaiiYuee  ...   Positive  Manchester City
# 5              52102899           D_Lusk  ...    Neutral          Neutral
# 6             110366369   hustla4sho_213  ...    Neutral  Manchester City
# 7            1291586280      _BhekumuziG  ...   Positive  Manchester City
# 8    733686121968881664           __sugy  ...   Positive  Manchester City
# 9             518715968  NBCSportsSoccer  ...    Neutral          Neutral
# 10  1216651467895058432     EfiaOkorewaa  ...   Negative  Manchester City
# 11  1347892685814771712          PeguyDj  ...   Positive  Manchester City
# 12            919149067         ZurFaies  ...   Positive  Manchester City
# 13           2360551094       cashthib68  ...   Positive  Manchester City
# 14  1391670619737976833         kobe__38  ...   Positive  Manchester City
#
# [15 rows x 14 columns]

# %% [markdown]
# Infine, si binarizzano le label sul sentiment per facilitare il processing successivo.

# %%
def Neut_bin(label):
  if label == "Neutral":
    return 1
  else:
    return 0

def Pos_bin(label):
  if label == "Positive":
    return 1
  else:
    return 0

def Neg_bin(label):
  if label == "Negative":
    return 1
  else:
    return 0

# %%
df_T_clean["Positive"] = df_T_clean["comp_score"].apply(Pos_bin)
df_T_clean["Negative"] = df_T_clean["comp_score"].apply(Neg_bin)
df_T_clean["Neutral"] = df_T_clean["comp_score"].apply(Neut_bin)

df_T_clean.head(15)
# Out:
#                 user_id      screen_name  ... Negative  Neutral
# 0    837362634005454848          nayupoy  ...        0        1
# 1              38991991   iMustPandaLean  ...        0        0
# 2             518715968  NBCSportsSoccer  ...        0        0
# 3   1261979991224565760       cityscoop_  ...        0        1
# 4            2177947717         WaiiYuee  ...        0        0
# 5              52102899           D_Lusk  ...        0        1
# 6             110366369   hustla4sho_213  ...        0        1
# 7            1291586280      _BhekumuziG  ...        0        0
# 8    733686121968881664           __sugy  ...        0        0
# 9             518715968  NBCSportsSoccer  ...        0        1
# 10  1216651467895058432     EfiaOkorewaa  ...        1        0
# 11  1347892685814771712          PeguyDj  ...        0        0
# 12            919149067         ZurFaies  ...        0        0
# 13           2360551094       cashthib68  ...        0        0
# 14  1391670619737976833         kobe__38  ...        0        0
#
# [15 rows x 17 columns]

# %% [markdown]
# Si conservano solamente le colonne d'interesse

# %%
df_final = df_T_clean.drop('scores', axis = 1)
df_final.head(15)
# Out:
#                 user_id      screen_name  ... Negative  Neutral
# 0    837362634005454848          nayupoy  ...        0        1
# 1              38991991   iMustPandaLean  ...        0        0
# 2             518715968  NBCSportsSoccer  ...        0        0
# 3   1261979991224565760       cityscoop_  ...        0        1
# 4            2177947717         WaiiYuee  ...        0        0
# 5              52102899           D_Lusk  ...        0        1
# 6             110366369   hustla4sho_213  ...        0        1
# 7            1291586280      _BhekumuziG  ...        0        0
# 8    733686121968881664           __sugy  ...        0        0
# 9             518715968  NBCSportsSoccer  ...        0        1
# 10  1216651467895058432     EfiaOkorewaa  ...        1        0
# 11  1347892685814771712          PeguyDj  ...        0        0
# 12            919149067         ZurFaies  ...        0        0
# 13           2360551094       cashthib68  ...        0        0
# 14  1391670619737976833         kobe__38  ...        0        0
#
# [15 rows x 16 columns]

# %%
df_final.to_csv("City_clean.csv")
