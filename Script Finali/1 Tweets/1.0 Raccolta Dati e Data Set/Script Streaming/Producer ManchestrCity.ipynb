# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import tweepy
from kafka import KafkaProducer
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
from tweepy import Stream
import json



# Declare a Python class (MyListener) that inherit from tweepy.StreamListener
# Then we override the on_status method that will be automatically used once
# Twitter "sends" us a new tweet.
class MyListener(StreamListener):
    
  def __init__(self, producer, producer_topic):
    super().__init__()
    self.producer = producer
    self.producer_topic = producer_topic

  def on_status(self, status):
    def full():
      if 'extended_tweet' in status._json:
        full = status.extended_tweet['full_text']
        return full
      else:
        return ''
    tweet = {
      'user_id': status.user.id,
      'username': status.user.name,
      'screen_name': status.user.screen_name,
      'text': status.text,
      'full_text': full(),
      'hashtags': [],
      'retweeted' : status.retweeted,
      'retweet_count': status.retweet_count,
      'favorite': status.favorite_count,
      'followers': status.user.followers_count
      'created_at': status.created_at
    }
    if status.entities.get('hashtags') is not None:
      hashtags = status.entities.get('hashtags')
      tweet['hashtags'] = [ h.get('text') for h in hashtags ]
    self.producer.send(topic=self.producer_topic, value=tweet)
    if 'extended_tweet' in status._json:
        print (status.extended_tweet["full_text"])
    

# Set consumer key, consumer secret, access token and access token secret
# Read them from your Twitter dev page
consumer_key = "8pn01oAB0VhA9IGzWoIYhatW5"
consumer_secret = "4RLFOc4whSglDRbIC99a0xiJqFWkUML9x4VvseDyAvwIJei4K4"
access_token = "1248576445-PlmdTFQCMKN3PTejK6bYv43iShtHtfIm99Hca9V"
access_token_secret = "HlvYJN0bqvINQt6wQjcTQqTvA2bVTz1MIushKE1mTh5PP"

# Authenticate with the OAuth protocol
# See: https://en.wikipedia.org/wiki/OAuth
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# Get the API object passing the authentication object
# See http://docs.tweepy.org/en/latest/api.html to discover the available methods
api = tweepy.API(auth)

producer = KafkaProducer(
  bootstrap_servers=["kafka:9092"],
  api_version=(0,11,5),
  value_serializer=lambda v: json.dumps(v).encode("utf-8"))

listener = MyListener(producer=producer, producer_topic="Manchester")
# We need an api to stream, so we reuse the api object we create before.
# Thus, we create a Stream object.
stream = Stream(auth = api.auth, listener=listener, tweet_mode="extended")


# A number of twitter streams are available through Tweepy.
# For more information on the capabilities and limitations of the different
# streams see Twitter Streaming API Documentation.

# In this example we will use filter to stream all tweets containing the word "Milano".
# The track parameter is an array of search terms to stream.
stream.filter(track=["#mancity", "#manchestercityfc", "#manchestercity", "#mcfc"], languages=["en"])
# Out:
# Che vergogna🤔
# Anche una commemorazione popolare di #Genova finisce in una passerella di ricconi che sfilano davanti alle telecamere con sorrisoni indegni.
# Fate partecipare il popolo i residenti del quartiere distrutto non i bauscia di Milano in vacanza a Genova
# #PonteMorandi 💔
# Ho letto che c’è gente che si è indignata perché Conte ha dichiarato la Lombardia “locomotiva d’Italia”.
# Ragazzi Milano è la capitale finanziaria accettatelo
# @janavel7 Tutta gente che non conoscono i numeri e non hanno nessuna idea degli ordini di grandezza. Probabilmente la popolazione under 10 di Milano non arriva complessivamente a 200000
# @ziopippi @Terra_Pianeta Pure il candidato di destra a Milano ha fatto le stesse affermazioni, invece di andare avanti si va indietro.
# Vuole cancellare l'unica cosa decente che ha fatto Sala in mezzo a 1000 disastri.
# @bbbnzl30 Effettivamente ha preso tutti per il culo. Ha fatto credere di essere nato nerazzurro, di aver trovato la squadra della sua vita, il "re di Milano". I tifosi interisti lo osannavano manco fosse Zanetti (lui si bandiera interista). E invece si è scoperto che tifava Chelsea. 😂😂
# @FusatoRiccardo fusato....spero tu stia scherzando🤣🤣...vabbè che ti devi riprendere ancora dalla partenza del re di Londra..ex Milano....   scusa..giroud..b.toure..chi li ha presi?
# @GiuseppeConteIT Ma lei davvero pensa che Milano e i milanesi avessero bisogno di questa lettera? E che il contenuto, al di là della propaganda per tener viva la platea dei creduloni, sia di qualche utilità? Vorrei sentire il sindaco Sala in merito, spero decida di esprimersi.
# @BimbiMeb Non ho partecipato perchè non sapevo proprio cosa rispondere, lo avrei fatto a casaccio.
# Comunque da Milanese sono fiera di dirvi che Milano è verde.
# Ci sono tanti parchi di qualità e giardini incantati.🤣
# Ecco la vista spettacolare dello skyline di Milano.😀 https://t.co/aOqAGmqTBm
# @fondamentalisti La responsabilità è della famiglia Zhang. Il ritorno di Lukaku a Milano avverrà tra due o tre anni, Per me non ci sarano problemi. In Premier ha già fallito, e fallirà di nuovo. Contro Magnani del Verona non ha toccato palla, la stessa cosa contro i difensori fisici inglesi,
# @TheRedCreed94 @toromaniaa @LineaJimmy @InterCM16 @Gazzetta_it Ma poi toromania, a foto della chiesetta a milano e viene da chissa' che collina abbruzzese.
# Un po confuso il tizio.
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     303         try:
# --> 304             return self.connection.recv_into(*args, **kwargs)
#     305         except OpenSSL.SSL.SysCallError as e:
#
# /opt/conda/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /opt/conda/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-236fd0be0e17> in <module>
#      81 # In this example we will use filter to stream all tweets containing the word "Milano".
#      82 # The track parameter is an array of search terms to stream.
# ---> 83 stream.filter(track=["Milano"], languages=["it"])
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# /opt/conda/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# /opt/conda/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     477             else:
#     478                 cache_content = False
# --> 479                 data = self._fp.read(amt)
#     480                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     481                     # Close the connection when no data is returned
#
# /opt/conda/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# /opt/conda/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# /opt/conda/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# /opt/conda/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# /opt/conda/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# /opt/conda/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/conda/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     314                 raise
#     315         except OpenSSL.SSL.WantReadError:
# --> 316             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     317                 raise timeout('The read operation timed out')
#     318             else:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
# ?/bin/bash
# Out:
# Object `/bin/bash` not found.

# %%
# ?server.properties
# Out:
# Object `server.properties` not found.

# %%
# !ls
# Out:
# "ls" non è riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.
