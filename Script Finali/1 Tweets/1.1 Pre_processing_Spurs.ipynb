# %% [markdown]
# Importazione Librerie per pre-processing

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# Importazione dataset tweet

# %%
df = pd.read_json('Spurs.json', lines=True)
df.head(15)
# Out:
#                 user_id                 username  ... followers          created_at
# 0              69871991                    James  ...       263 2021-08-15 14:54:30
# 1              85367934            Paul Mckenzie  ...       565 2021-08-15 14:54:30
# 2   1266830735912194048             Brandon Doan  ...       233 2021-08-15 14:54:36
# 3              27957972               Rob Aycock  ...       393 2021-08-15 14:54:37
# 4             376333378  🍌⚽️🤩 kev bananaman 🍌⚽️🤩  ...      1943 2021-08-15 14:54:37
# 5   1375839513906278403                     なおやん  ...       287 2021-08-15 14:54:40
# 6            1126381076                   AJS 🇮🇱  ...       563 2021-08-15 14:54:42
# 7    773216092403666944                   Aaaron  ...       583 2021-08-15 14:54:44
# 8             227448013            thejondaniels  ...      2308 2021-08-15 14:54:44
# 9   1117479778792030208              🐐 𝓶𝓻.𝓓𝓘𝓔𝓡 🍑  ...       151 2021-08-15 14:54:45
# 10  1061554145172238336                    もなお☃️  ...       409 2021-08-15 14:54:45
# 11            182948486       Bounty Junior 🇯🇲🇬🇾  ...       673 2021-08-15 14:54:46
# 12  1425137066938011649                        .  ...       385 2021-08-15 14:54:47
# 13           2545753046            Kevin Sheehan  ...        35 2021-08-15 14:54:48
# 14             91628625            SNWDN ❄️ COYS  ...       806 2021-08-15 14:54:49
#
# [15 rows x 11 columns]

# %% [markdown]
# Check sui type del dataset

# %%
df.dtypes
# Out:
# user_id                   int64
# username                 object
# screen_name              object
# text                     object
# full_text                object
# hashtags                 object
# retweeted                  bool
# retweet_count             int64
# favorite                  int64
# followers                 int64
# created_at       datetime64[ns]
# dtype: object

# %% [markdown]
# Il type degli attributi è corretto tranne per user_id, si provvede a correggerlo

# %%
df["user_id"] = df["user_id"].astype(str, copy = False)
df.dtypes
# Out:
# user_id                  object
# username                 object
# screen_name              object
# text                     object
# full_text                object
# hashtags                 object
# retweeted                  bool
# retweet_count             int64
# favorite                  int64
# followers                 int64
# created_at       datetime64[ns]
# dtype: object

# %% [markdown]
# Check su presenza retweet o favorite

# %%
check_rt = df[df['retweeted'] == True]
len(check_rt)
# Out:
# 0

# %%
check_fv = df[df['favorite'] == 1]
len(check_fv)
# Out:
# 0

# %%
check_rtc = df[df['retweet_count'] > 0]
len(check_rtc)
# Out:
# 0

# %% [markdown]
# Non sono presenti retweet o favorite
#
# Si eliminano i campi non rilevanti e si riordinano gli attributi

# %%
df = df.drop(['retweet_count', 'favorite', 'retweeted'], axis = 1)
df.head(15)
# Out:
#                 user_id                 username  ... followers          created_at
# 0              69871991                    James  ...       263 2021-08-15 14:54:30
# 1              85367934            Paul Mckenzie  ...       565 2021-08-15 14:54:30
# 2   1266830735912194048             Brandon Doan  ...       233 2021-08-15 14:54:36
# 3              27957972               Rob Aycock  ...       393 2021-08-15 14:54:37
# 4             376333378  🍌⚽️🤩 kev bananaman 🍌⚽️🤩  ...      1943 2021-08-15 14:54:37
# 5   1375839513906278403                     なおやん  ...       287 2021-08-15 14:54:40
# 6            1126381076                   AJS 🇮🇱  ...       563 2021-08-15 14:54:42
# 7    773216092403666944                   Aaaron  ...       583 2021-08-15 14:54:44
# 8             227448013            thejondaniels  ...      2308 2021-08-15 14:54:44
# 9   1117479778792030208              🐐 𝓶𝓻.𝓓𝓘𝓔𝓡 🍑  ...       151 2021-08-15 14:54:45
# 10  1061554145172238336                    もなお☃️  ...       409 2021-08-15 14:54:45
# 11            182948486       Bounty Junior 🇯🇲🇬🇾  ...       673 2021-08-15 14:54:46
# 12  1425137066938011649                        .  ...       385 2021-08-15 14:54:47
# 13           2545753046            Kevin Sheehan  ...        35 2021-08-15 14:54:48
# 14             91628625            SNWDN ❄️ COYS  ...       806 2021-08-15 14:54:49
#
# [15 rows x 8 columns]

# %%
df = df[['created_at', 'user_id',	'username',	'screen_name',	'text',	'full_text',	'hashtags',	'followers']]
df.head(15)
# Out:
#             created_at              user_id  ...              hashtags followers
# 0  2021-08-15 14:54:30             69871991  ...                [thfc]       263
# 1  2021-08-15 14:54:30             85367934  ...                    []       565
# 2  2021-08-15 14:54:36  1266830735912194048  ...  [THFC, MCFC, TOTMCI]       233
# 3  2021-08-15 14:54:37             27957972  ...                    []       393
# 4  2021-08-15 14:54:37            376333378  ...                [THFC]      1943
# 5  2021-08-15 14:54:40  1375839513906278403  ...                [THFC]       287
# 6  2021-08-15 14:54:42           1126381076  ...                [COYS]       563
# 7  2021-08-15 14:54:44   773216092403666944  ...  [Tottenham, ManCity]       583
# 8  2021-08-15 14:54:44            227448013  ...                [COYS]      2308
# 9  2021-08-15 14:54:45  1117479778792030208  ...                [COYS]       151
# 10 2021-08-15 14:54:45  1061554145172238336  ...                [COYS]       409
# 11 2021-08-15 14:54:46            182948486  ...                    []       673
# 12 2021-08-15 14:54:47  1425137066938011649  ...                    []       385
# 13 2021-08-15 14:54:48           2545753046  ...                    []        35
# 14 2021-08-15 14:54:49             91628625  ...                [COYS]       806
#
# [15 rows x 8 columns]

# %% [markdown]
# Si crea una nuova colonna per il testo che consideri il full text dove presente e il text in caso contrario

# %%
def text(row):
  if len(row['full_text']) > len(row['text']):
    return row['full_text']   
  else:
    return row['text']

# %%
df['text_clean'] = df.apply(text, axis=1)
df.head(15)
# Out:
#             created_at  ...                                         text_clean
# 0  2021-08-15 14:54:30  ...  There will be positives today whatever happens...
# 1  2021-08-15 14:54:30  ...  @TheSpursgirl @thfc @ManCity Hey Jane, where a...
# 2  2021-08-15 14:54:36  ...  RT @talkSPORT: Jack Grealish gets the nod for ...
# 3  2021-08-15 14:54:37  ...  Nuno is sending a strong message by leaving bo...
# 4  2021-08-15 14:54:37  ...  RT @FreeBetsFooty: 🚨 GIVEAWAY 🚨\n\nIf Son Heun...
# 5  2021-08-15 14:54:40  ...  RT @thespursweb: 🚨 NEW: Harry Kane was NOT on ...
# 6  2021-08-15 14:54:42  ...                                #COYS no pressure x
# 7  2021-08-15 14:54:44  ...  RT @GrosvenorSport: Who will Kane by playing f...
# 8  2021-08-15 14:54:44  ...  #COYS Kane was never gonna be in the squad.  B...
# 9  2021-08-15 14:54:45  ...  RT @thespursweb: 🎶 I want to be in that number...
# 10 2021-08-15 14:54:45  ...  RT @thespursweb: 🎶 I want to be in that number...
# 11 2021-08-15 14:54:46  ...                                             This!!
# 12 2021-08-15 14:54:47  ...                             Parry pane is finished
# 13 2021-08-15 14:54:48  ...  No Kane, nDombele, Rodon, Sessegnon or Aurier ...
# 14 2021-08-15 14:54:49  ...  RT @thespursweb: 🎶 I want to be in that number...
#
# [15 rows x 9 columns]

# %% [markdown]
# Si opera adesso sugli hashtag, si recuperano gli hashtag presenti nel testo

# %%
def hashtags(row):
  compi1 = re.compile('(#[Mm]an[Cc]ity)')
  compi2 = re.compile('(#[Mm]anchester[Cc]ity[Ff]c)')
  compi3 = re.compile('(#[Mm]anchester[Cc]ity)')
  compi4 = re.compile('(#[Mm][Cc][Ff][Cc])')
  compi5 = re.compile('(#[Pp]remier[Ll]eague)')
  compi6 = re.compile('(#[Pp][Ll])')
  compi7 = re.compile('(#[Tt]ottenham)')
  compi8 = re.compile('(#[Ss]purs)')
  compi9 = re.compile('(#[Cc][Oo][Yy][Ss])')
  compi10 = re.compile('(#[Tt][Hh][Ff][Cc])')
  compi11 = re.compile('(#TOTMCI)')

  hast = []
  
  subs1 = compi1.search(row['text_clean'])
  subs2 = compi2.search(row['text_clean'])
  subs3 = compi3.search(row['text_clean'])
  subs4 = compi4.search(row['text_clean'])
  subs5 = compi5.search(row['text_clean'])
  subs6 = compi6.search(row['text_clean'])
  subs7 = compi7.search(row['text_clean'])
  subs8 = compi8.search(row['text_clean'])
  subs9 = compi9.search(row['text_clean'])
  subs10 = compi10.search(row['text_clean'])
  subs11 = compi11.search(row['text_clean'])

  if subs1:
    if subs1.group(1) not in df['hashtags']: 
      hast.append(subs1.group(1).strip('#'))
  if subs2:
    if subs2.group(1) not in df['hashtags']:
      hast.append(subs2.group(1).strip('#'))
  if subs3:
    if subs3.group(1) not in df['hashtags']:
      hast.append(subs3.group(1).strip('#'))
  if subs4:
    if subs4.group(1) not in df['hashtags']:
      hast.append(subs4.group(1).strip('#'))
  if subs5:   
    if subs5.group(1) not in df['hashtags']:
      hast.append(subs5.group(1).strip('#'))
  if subs6:
    if subs6.group(1) not in df['hashtags']:
      hast.append(subs6.group(1).strip('#'))
  if subs7:
    if subs7.group(1) not in df['hashtags']:
      hast.append(subs7.group(1).strip('#'))
  if subs8:
    if subs8.group(1) not in df['hashtags']:
      hast.append(subs8.group(1).strip('#'))
  if subs9:   
    if subs9.group(1) not in df['hashtags']:
      hast.append(subs9.group(1).strip('#'))
  if subs10:
    if subs10.group(1) not in df['hashtags']:
      hast.append(subs10.group(1).strip('#'))
  if subs11:
    if subs11.group(1) not in df['hashtags']:
      hast.append(subs11.group(1).strip('#'))           
  return hast

# %%
df['has']=df.apply(hashtags, axis=1)

# %% [markdown]
# Si concatenano gli hashtag ottenuti dallo streaming e dal testo ed eliminando i duplicati si hanno tutti gli hashtag presenti nel tweet

# %%
df['hashtag_fin'] = df['hashtags'] + df['has']

# %%
def hashtag_puliti(row):
  np.array(row['hashtag_fin'])
  fi= np.unique(row['hashtag_fin'])
  return fi

# %%
df['compl_hashtags'] = df.apply(hashtag_puliti, axis=1)
df.head(15)
# Out:
#             created_at  ...         compl_hashtags
# 0  2021-08-15 14:54:30  ...                 [thfc]
# 1  2021-08-15 14:54:30  ...    [COYS, Spurs, thfc]
# 2  2021-08-15 14:54:36  ...   [MCFC, THFC, TOTMCI]
# 3  2021-08-15 14:54:37  ...           [COYS, THFC]
# 4  2021-08-15 14:54:37  ...                 [THFC]
# 5  2021-08-15 14:54:40  ...                 [THFC]
# 6  2021-08-15 14:54:42  ...                 [COYS]
# 7  2021-08-15 14:54:44  ...   [ManCity, Tottenham]
# 8  2021-08-15 14:54:44  ...                 [COYS]
# 9  2021-08-15 14:54:45  ...                 [COYS]
# 10 2021-08-15 14:54:45  ...                 [COYS]
# 11 2021-08-15 14:54:46  ...                     []
# 12 2021-08-15 14:54:47  ...                     []
# 13 2021-08-15 14:54:48  ...  [Coys, Spurs, TOTMCI]
# 14 2021-08-15 14:54:49  ...                 [COYS]
#
# [15 rows x 12 columns]

# %% [markdown]
# Si assume nel tentativo di attribuire l'appartenenza ad una tifoseria che sia necessaria la presenza di hashtag all'elaborazione

# %%
def selezione(row):
  lung = len(row['compl_hashtags'])
  if lung != 0:
    return 'Yes'
  else:
    return 'No'

# %%
df['Keep'] = df.apply(selezione, axis =1)
df_clean = df[df['Keep'] == "Yes"]
df_clean.head(15)
# Out:
#             created_at              user_id  ...         compl_hashtags Keep
# 0  2021-08-15 14:54:30             69871991  ...                 [thfc]  Yes
# 1  2021-08-15 14:54:30             85367934  ...    [COYS, Spurs, thfc]  Yes
# 2  2021-08-15 14:54:36  1266830735912194048  ...   [MCFC, THFC, TOTMCI]  Yes
# 3  2021-08-15 14:54:37             27957972  ...           [COYS, THFC]  Yes
# 4  2021-08-15 14:54:37            376333378  ...                 [THFC]  Yes
# 5  2021-08-15 14:54:40  1375839513906278403  ...                 [THFC]  Yes
# 6  2021-08-15 14:54:42           1126381076  ...                 [COYS]  Yes
# 7  2021-08-15 14:54:44   773216092403666944  ...   [ManCity, Tottenham]  Yes
# 8  2021-08-15 14:54:44            227448013  ...                 [COYS]  Yes
# 9  2021-08-15 14:54:45  1117479778792030208  ...                 [COYS]  Yes
# 10 2021-08-15 14:54:45  1061554145172238336  ...                 [COYS]  Yes
# 13 2021-08-15 14:54:48           2545753046  ...  [Coys, Spurs, TOTMCI]  Yes
# 14 2021-08-15 14:54:49             91628625  ...                 [COYS]  Yes
# 15 2021-08-15 14:54:49   702943194955321344  ...           [COYS, THFC]  Yes
# 17 2021-08-15 14:54:51           2561850986  ...                 [COYS]  Yes
#
# [15 rows x 13 columns]

# %% [markdown]
# Si tratta adesso la variabile tempo (created_at)
#
# Si importa la libreria necessaria a trattare date e orari

# %%
from datetime import *

# %% [markdown]
# Abbiamo inziato lo streaming dei tweet circa alle 16:55, si nota pertanto che nel dataset l'orario di creazione del tweet è riportato con due ore di differenza, presumibilmente dovute al fuso orario. Con la seguente funzione si compensa questo valore per riportarsi all'orario italiano.

# %%
def time(loc_date_time):
    date_time = loc_date_time + timedelta(hours = 2)
    return date_time 

df_clean['time'] = df_clean['created_at'].apply(time)

df_clean.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#             created_at              user_id  ... Keep                time
# 0  2021-08-15 14:54:30             69871991  ...  Yes 2021-08-15 16:54:30
# 1  2021-08-15 14:54:30             85367934  ...  Yes 2021-08-15 16:54:30
# 2  2021-08-15 14:54:36  1266830735912194048  ...  Yes 2021-08-15 16:54:36
# 3  2021-08-15 14:54:37             27957972  ...  Yes 2021-08-15 16:54:37
# 4  2021-08-15 14:54:37            376333378  ...  Yes 2021-08-15 16:54:37
# 5  2021-08-15 14:54:40  1375839513906278403  ...  Yes 2021-08-15 16:54:40
# 6  2021-08-15 14:54:42           1126381076  ...  Yes 2021-08-15 16:54:42
# 7  2021-08-15 14:54:44   773216092403666944  ...  Yes 2021-08-15 16:54:44
# 8  2021-08-15 14:54:44            227448013  ...  Yes 2021-08-15 16:54:44
# 9  2021-08-15 14:54:45  1117479778792030208  ...  Yes 2021-08-15 16:54:45
# 10 2021-08-15 14:54:45  1061554145172238336  ...  Yes 2021-08-15 16:54:45
# 13 2021-08-15 14:54:48           2545753046  ...  Yes 2021-08-15 16:54:48
# 14 2021-08-15 14:54:49             91628625  ...  Yes 2021-08-15 16:54:49
# 15 2021-08-15 14:54:49   702943194955321344  ...  Yes 2021-08-15 16:54:49
# 17 2021-08-15 14:54:51           2561850986  ...  Yes 2021-08-15 16:54:51
#
# [15 rows x 14 columns]

# %% [markdown]
# Dovendo far riferimento al minuto della partita si è ritenuto opportuno riportarsi ad una situazione di tempo discretizzato a 15 secondi.

# %%
time_time = pd.concat([pd.Series(df_clean["time"].dt.hour),
                       pd.Series(df_clean["time"].dt.minute),
                       pd.Series(df_clean["time"].dt.second)],axis=1)

# %%
time_time["hour"] = time_time.iloc[:,0]
time_time["minute"] = time_time.iloc[:,1]
time_time["second"] = time_time.iloc[:,2]

# %%
time_time["second"] = time_time["second"]/15
time_time["second"] = time_time["second"].round()
time_time["second"] = time_time["second"]*15

# %%
time_time.loc[time_time["second"] == 60.0,"minute"] = time_time["minute"] + 1
time_time.loc[time_time["second"] == 60.0,"second"] = time_time["second"] -60
time_time.loc[time_time["minute"] == 60.0,"hour"] = time_time["hour"] + 1
time_time.loc[time_time["minute"] == 60.0,"minute"] = time_time["minute"] -60
time_time.loc[time_time["second"] == 0.0,"second"] = "00"
time_time.loc[time_time["second"] == 15.0,"second"] = "15"
time_time.loc[time_time["second"] == 30.0,"second"] = "30"
time_time.loc[time_time["second"] == 45.0,"second"] = "45"

# %%
time_time["hour"] = time_time["hour"].apply(lambda x: str(x))
time_time["minute"] = time_time["minute"].apply(lambda x: str(x))
time_time["second"] = time_time["second"].apply(lambda x: str(x))

# %%
time_time = pd.Series("2021/08/15 " + time_time["hour"] + ":" + time_time["minute"] + ":" + time_time["second"])
time_time = time_time.apply(lambda x: str(x)).copy()

# %%
def converttime(dstring):
    return datetime.strptime(dstring, "%Y/%m/%d %H:%M:%S")

# %%
time_time = time_time.apply(lambda x: converttime(x)).copy() #non so togliere warning copy
df_clean["disc_time"] = time_time
df_clean.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             created_at  ...           disc_time
# 0  2021-08-15 14:54:30  ... 2021-08-15 16:54:30
# 1  2021-08-15 14:54:30  ... 2021-08-15 16:54:30
# 2  2021-08-15 14:54:36  ... 2021-08-15 16:54:30
# 3  2021-08-15 14:54:37  ... 2021-08-15 16:54:30
# 4  2021-08-15 14:54:37  ... 2021-08-15 16:54:30
# 5  2021-08-15 14:54:40  ... 2021-08-15 16:54:45
# 6  2021-08-15 14:54:42  ... 2021-08-15 16:54:45
# 7  2021-08-15 14:54:44  ... 2021-08-15 16:54:45
# 8  2021-08-15 14:54:44  ... 2021-08-15 16:54:45
# 9  2021-08-15 14:54:45  ... 2021-08-15 16:54:45
# 10 2021-08-15 14:54:45  ... 2021-08-15 16:54:45
# 13 2021-08-15 14:54:48  ... 2021-08-15 16:54:45
# 14 2021-08-15 14:54:49  ... 2021-08-15 16:54:45
# 15 2021-08-15 14:54:49  ... 2021-08-15 16:54:45
# 17 2021-08-15 14:54:51  ... 2021-08-15 16:54:45
#
# [15 rows x 15 columns]

# %% [markdown]
# Va riportato adesso l'orario al riferimento temporale nella partita ovvero il minuto del match.
#
# La partita è iniziata puntualmente alle 17:30, sono stati concessi 2 minuti di recupero nel primo tempo e 6 nel secondo. L'intervallo è durato regolarmente circa 15 minuti. Si ipotizza, inoltre, un compenso di circa un minuto tra evento della partita e pubblicazione del tweet. La durata dell'evento incluso l'intervallo è stata di 113 minuti.
#
# Si fa una prima discrimanzione tra tweet pubblicati durante o a ridosso della partita e gli altri.

# %%
def minute_from_start(loc_date_time):
    
    date_time = loc_date_time - timedelta(hours = 17, minutes = 31)
    
    if date_time.day == 14: # escludo pre-partita
        minute = np.nan
    
    elif date_time.hour == 0:
        minute = date_time.minute
         
    else: 
        minute =  date_time.minute + date_time.hour*60
        
    return minute

# %%
df_clean['minute_from_start'] = df_clean['disc_time'].apply(minute_from_start)
df_clean.tail(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                created_at  ... minute_from_start
# 26858 2021-08-15 18:30:36  ...             179.0
# 26860 2021-08-15 18:30:39  ...             179.0
# 26861 2021-08-15 18:30:40  ...             179.0
# 26862 2021-08-15 18:30:41  ...             179.0
# 26863 2021-08-15 18:30:41  ...             179.0
# 26864 2021-08-15 18:30:41  ...             179.0
# 26866 2021-08-15 18:30:42  ...             179.0
# 26867 2021-08-15 18:30:42  ...             179.0
# 26869 2021-08-15 18:30:43  ...             179.0
# 26870 2021-08-15 18:30:43  ...             179.0
# 26871 2021-08-15 18:30:45  ...             179.0
# 26873 2021-08-15 18:30:48  ...             179.0
# 26874 2021-08-15 18:30:48  ...             179.0
# 26875 2021-08-15 18:30:49  ...             179.0
# 26876 2021-08-15 18:30:51  ...             179.0
#
# [15 rows x 16 columns]

# %% [markdown]
# Suddivido i tweet in Pre-partita, Intervallo, Primo Tempo, Secondo Tempo e Post-Partita

# %%
def pre_partita(minute):
  try:
      if np.isnan(minute) == True:
        moment = "Pre"
      else:
        moment = "Other"
  except:
    moment = "Other"
  return moment

# %%
df_clean['Moment'] = df_clean['minute_from_start'].apply(pre_partita)
df_clean.head(15)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             created_at              user_id  ... minute_from_start Moment
# 0  2021-08-15 14:54:30             69871991  ...               NaN    Pre
# 1  2021-08-15 14:54:30             85367934  ...               NaN    Pre
# 2  2021-08-15 14:54:36  1266830735912194048  ...               NaN    Pre
# 3  2021-08-15 14:54:37             27957972  ...               NaN    Pre
# 4  2021-08-15 14:54:37            376333378  ...               NaN    Pre
# 5  2021-08-15 14:54:40  1375839513906278403  ...               NaN    Pre
# 6  2021-08-15 14:54:42           1126381076  ...               NaN    Pre
# 7  2021-08-15 14:54:44   773216092403666944  ...               NaN    Pre
# 8  2021-08-15 14:54:44            227448013  ...               NaN    Pre
# 9  2021-08-15 14:54:45  1117479778792030208  ...               NaN    Pre
# 10 2021-08-15 14:54:45  1061554145172238336  ...               NaN    Pre
# 13 2021-08-15 14:54:48           2545753046  ...               NaN    Pre
# 14 2021-08-15 14:54:49             91628625  ...               NaN    Pre
# 15 2021-08-15 14:54:49   702943194955321344  ...               NaN    Pre
# 17 2021-08-15 14:54:51           2561850986  ...               NaN    Pre
#
# [15 rows x 17 columns]

# %%
pre_match = df_clean[df_clean["Moment"] == "Pre"].copy()
match_post = df_clean[df_clean["Moment"] == "Other"].copy()
match_post.head(15)
# Out:
#               created_at              user_id  ... minute_from_start Moment
# 2627 2021-08-15 15:30:53   837362634005454848  ...               0.0  Other
# 2629 2021-08-15 15:30:53            576167561  ...               0.0  Other
# 2630 2021-08-15 15:30:53            518715968  ...               0.0  Other
# 2631 2021-08-15 15:30:54  1261979991224565760  ...               0.0  Other
# 2632 2021-08-15 15:30:53            266251364  ...               0.0  Other
# 2633 2021-08-15 15:30:54             52102899  ...               0.0  Other
# 2634 2021-08-15 15:30:55            518715968  ...               0.0  Other
# 2635 2021-08-15 15:30:58            276233686  ...               0.0  Other
# 2636 2021-08-15 15:30:58           2360551094  ...               0.0  Other
# 2637 2021-08-15 15:30:58   781870022293618688  ...               0.0  Other
# 2638 2021-08-15 15:30:58            161413417  ...               0.0  Other
# 2639 2021-08-15 15:31:00           1257180002  ...               0.0  Other
# 2640 2021-08-15 15:31:00             24518986  ...               0.0  Other
# 2641 2021-08-15 15:31:00  1016579178290794497  ...               0.0  Other
# 2642 2021-08-15 15:31:00            338670340  ...               0.0  Other
#
# [15 rows x 17 columns]

# %%
len(pre_match) + len(match_post) == len(df_clean)
# Out:
# True

# %%
def momento(minute):
  if minute <= 46:
    moment = "Primo"
  elif minute > 112:
    moment = "Post"  
  elif (minute > 46) & (minute <= 61):
    moment = "Intervallo"
  else:
    moment = "Secondo"
  
  return moment

# %%
match_post['Moment'] = match_post['minute_from_start'].apply(momento)
match_post.head(15)
# Out:
#               created_at              user_id  ... minute_from_start Moment
# 2627 2021-08-15 15:30:53   837362634005454848  ...               0.0  Primo
# 2629 2021-08-15 15:30:53            576167561  ...               0.0  Primo
# 2630 2021-08-15 15:30:53            518715968  ...               0.0  Primo
# 2631 2021-08-15 15:30:54  1261979991224565760  ...               0.0  Primo
# 2632 2021-08-15 15:30:53            266251364  ...               0.0  Primo
# 2633 2021-08-15 15:30:54             52102899  ...               0.0  Primo
# 2634 2021-08-15 15:30:55            518715968  ...               0.0  Primo
# 2635 2021-08-15 15:30:58            276233686  ...               0.0  Primo
# 2636 2021-08-15 15:30:58           2360551094  ...               0.0  Primo
# 2637 2021-08-15 15:30:58   781870022293618688  ...               0.0  Primo
# 2638 2021-08-15 15:30:58            161413417  ...               0.0  Primo
# 2639 2021-08-15 15:31:00           1257180002  ...               0.0  Primo
# 2640 2021-08-15 15:31:00             24518986  ...               0.0  Primo
# 2641 2021-08-15 15:31:00  1016579178290794497  ...               0.0  Primo
# 2642 2021-08-15 15:31:00            338670340  ...               0.0  Primo
#
# [15 rows x 17 columns]

# %%
df_time = pd.concat([match_post, pre_match], ignore_index=True).copy()
df_time
# Out:
#                created_at              user_id  ... minute_from_start Moment
# 0     2021-08-15 15:30:53   837362634005454848  ...               0.0  Primo
# 1     2021-08-15 15:30:53            576167561  ...               0.0  Primo
# 2     2021-08-15 15:30:53            518715968  ...               0.0  Primo
# 3     2021-08-15 15:30:54  1261979991224565760  ...               0.0  Primo
# 4     2021-08-15 15:30:53            266251364  ...               0.0  Primo
# ...                   ...                  ...  ...               ...    ...
# 21235 2021-08-15 15:30:48             18982817  ...               NaN    Pre
# 21236 2021-08-15 15:30:51           1176640496  ...               NaN    Pre
# 21237 2021-08-15 15:30:52            635579580  ...               NaN    Pre
# 21238 2021-08-15 15:30:52  1150482610545557505  ...               NaN    Pre
# 21239 2021-08-15 15:30:52           2735983895  ...               NaN    Pre
#
# [21240 rows x 17 columns]

# %% [markdown]
# Va costruita una funzione che attribuisca il minuto all'interno della partita.

# %%
def match_minute(row):
  st_minute = row['minute_from_start']
  moment = row['Moment']
  
  if moment == "Secondo":
    minuto = st_minute - 17 + 1
  
  elif moment == "Primo":
    minuto = st_minute + 1
  
  else:
    minuto = np.nan
  
  return minuto

# %%
df_time['Minute'] = df_time.apply(match_minute, axis = 1)
df_time[df_time['Minute'] == 47]
# Out:
#               created_at              user_id  ...   Moment Minute
# 1739 2021-08-15 16:16:53             35783746  ...    Primo   47.0
# 1740 2021-08-15 16:16:53  1331582016039526401  ...    Primo   47.0
# 1741 2021-08-15 16:16:54            309243917  ...    Primo   47.0
# 1742 2021-08-15 16:16:54  1273666845719982080  ...    Primo   47.0
# 1743 2021-08-15 16:16:57  1353358695162327043  ...    Primo   47.0
# ...                  ...                  ...  ...      ...    ...
# 2717 2021-08-15 16:34:44           3359172526  ...  Secondo   47.0
# 2718 2021-08-15 16:34:45  1373009135432794120  ...  Secondo   47.0
# 2719 2021-08-15 16:34:47            133783347  ...  Secondo   47.0
# 2720 2021-08-15 16:34:48   710857681926361088  ...  Secondo   47.0
# 2721 2021-08-15 16:34:52   850460422255898625  ...  Secondo   47.0
#
# [140 rows x 18 columns]

# %% [markdown]
# Con la seguente funzione si gestisce la questione minuti di recupero creando riferimenti univoci per il minuto della partita nel dataset.

# %%
def minute_str(row):
  
  minute = row['Minute']
  moment = row['Moment']
  
  if moment == "Primo":
    if minute <= 45:
      min = str(int(minute))
    else:
      rec = int(minute - 45)
      min = "45+"+str(rec)
  
  elif moment == "Secondo":
    if minute <= 90:
      min = str(int(minute))
    else:
      rec = int(minute - 90)
      min = "90+"+str(rec)
  
  else:
    min = np.nan
  
  return min

# %%
df_time['Min_Cronaca'] = df_time.apply(minute_str, axis = 1)
df_time
# Out:
#                created_at              user_id  ... Minute Min_Cronaca
# 0     2021-08-15 15:30:53   837362634005454848  ...    1.0           1
# 1     2021-08-15 15:30:53            576167561  ...    1.0           1
# 2     2021-08-15 15:30:53            518715968  ...    1.0           1
# 3     2021-08-15 15:30:54  1261979991224565760  ...    1.0           1
# 4     2021-08-15 15:30:53            266251364  ...    1.0           1
# ...                   ...                  ...  ...    ...         ...
# 21235 2021-08-15 15:30:48             18982817  ...    NaN         NaN
# 21236 2021-08-15 15:30:51           1176640496  ...    NaN         NaN
# 21237 2021-08-15 15:30:52            635579580  ...    NaN         NaN
# 21238 2021-08-15 15:30:52  1150482610545557505  ...    NaN         NaN
# 21239 2021-08-15 15:30:52           2735983895  ...    NaN         NaN
#
# [21240 rows x 19 columns]

# %%
df_time[df_time["Min_Cronaca"] == "46"]
# Out:
#               created_at              user_id  ... Minute Min_Cronaca
# 2668 2021-08-15 16:32:55           4885062587  ...   46.0          46
# 2669 2021-08-15 16:32:58            425989199  ...   46.0          46
# 2670 2021-08-15 16:33:00  1426288966416879618  ...   46.0          46
# 2671 2021-08-15 16:33:01   889243712005562372  ...   46.0          46
# 2672 2021-08-15 16:33:02             92619010  ...   46.0          46
# 2673 2021-08-15 16:33:04  1295477421421068289  ...   46.0          46
# 2674 2021-08-15 16:33:12  1099044049980411904  ...   46.0          46
# 2675 2021-08-15 16:33:12            303073418  ...   46.0          46
# 2676 2021-08-15 16:33:13             27010202  ...   46.0          46
# 2677 2021-08-15 16:33:16            228145535  ...   46.0          46
# 2678 2021-08-15 16:33:17            517870386  ...   46.0          46
# 2679 2021-08-15 16:33:18            153586655  ...   46.0          46
# 2680 2021-08-15 16:33:19  1356870038750449666  ...   46.0          46
# 2681 2021-08-15 16:33:22            166858762  ...   46.0          46
# 2682 2021-08-15 16:33:23           3170419704  ...   46.0          46
# 2683 2021-08-15 16:33:24   774362503614722049  ...   46.0          46
# 2684 2021-08-15 16:33:28            436969094  ...   46.0          46
# 2685 2021-08-15 16:33:29  1358722315874422784  ...   46.0          46
# 2686 2021-08-15 16:33:29  1406167240232288277  ...   46.0          46
# 2687 2021-08-15 16:33:29  1113601643084505088  ...   46.0          46
# 2688 2021-08-15 16:33:34             23886392  ...   46.0          46
# 2689 2021-08-15 16:33:35   829074676173389825  ...   46.0          46
# 2690 2021-08-15 16:33:41             41839007  ...   46.0          46
# 2691 2021-08-15 16:33:42  1412862488631185410  ...   46.0          46
# 2692 2021-08-15 16:33:43  1250352258585227265  ...   46.0          46
# 2693 2021-08-15 16:33:46            718967543  ...   46.0          46
#
# [26 rows x 19 columns]

# %%
df_T_clean = df_time.drop(['Minute', 'created_at', 'Keep', 'hashtag_fin','has', 'text', 'full_text', 'username', 'disc_time'], axis = 1)
df_T_clean
# Out:
#                    user_id      screen_name  ... Moment  Min_Cronaca
# 0       837362634005454848          nayupoy  ...  Primo            1
# 1                576167561      untriplesix  ...  Primo            1
# 2                518715968  NBCSportsSoccer  ...  Primo            1
# 3      1261979991224565760       cityscoop_  ...  Primo            1
# 4                266251364    lazqetjohnson  ...  Primo            1
# ...                    ...              ...  ...    ...          ...
# 21235             18982817      brookiemoop  ...    Pre          NaN
# 21236           1176640496   SteveStevens47  ...    Pre          NaN
# 21237            635579580       DamonAkers  ...    Pre          NaN
# 21238  1150482610545557505          lmpblkr  ...    Pre          NaN
# 21239           2735983895        ryankoley  ...    Pre          NaN
#
# [21240 rows x 10 columns]

# %% [markdown]
# Si procede ad attribuire l'appartenenza ad una tifoseria basandosi sugli hashtag citati e sulla relativa sentiment analysis.
#
# Di seguito l'importazione delle librerie utili.

# %%
import nltk
from nltk.stem import PorterStemmer
from gensim.parsing.preprocessing import remove_stopwords
import string
# !pip3 install vaderSentiment
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 7.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %% [markdown]
# Applichiamo una pulizia del testo per migliorare l'efficacia della sentiment analysis.

# %%
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub(r"RT","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub(r":","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub("@\w*","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub("#\w*","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda x: re.sub("\n","",x))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(str)
df_T_clean["text_clean"] = df_T_clean["text_clean"].str.lower()
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: re.sub(r"\d+", "",text))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: text.translate(str.maketrans('', '', string.punctuation)))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: remove_stopwords(text))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: re.sub(r"'", "",text))
df_T_clean["text_clean"] = df_T_clean["text_clean"].apply(lambda text: re.sub(r"https\w*", "",text))

# %% [markdown]
# Attribuzione degli score per la sentiment analysis.

# %%
sid = SentimentIntensityAnalyzer()
df_T_clean['scores'] = df_T_clean['text_clean'].apply(lambda review: sid.polarity_scores(review))
df_T_clean['compound']  = df_T_clean['scores'].apply(lambda score_dict: score_dict['compound'])
df_T_clean.head(15)
# Out:
#                 user_id  ... compound
# 0    837362634005454848  ...   0.0000
# 1             576167561  ...   0.0000
# 2             518715968  ...   0.3400
# 3   1261979991224565760  ...   0.0000
# 4             266251364  ...   0.6369
# 5              52102899  ...   0.0000
# 6             518715968  ...   0.0000
# 7             276233686  ...  -0.2500
# 8            2360551094  ...   0.3400
# 9    781870022293618688  ...   0.4588
# 10            161413417  ...   0.5106
# 11           1257180002  ...   0.0000
# 12             24518986  ...   0.0000
# 13  1016579178290794497  ...   0.8402
# 14            338670340  ...   0.0000
#
# [15 rows x 12 columns]

# %% [markdown]
# Viene attribuito ad ogni tweet una label circa il sentiment del tweet sulla base dello score ottenuto.

# %%
def comp_score(compund):
  if compund >=0.05:
    return 'Positive'
  elif compund <= -0.05:
    return 'Negative'
  else:
    return 'Neutral'

# %%
df_T_clean['comp_score'] = df_T_clean['compound'].apply(comp_score)
df_T_clean.head(15)
# Out:
#                 user_id      screen_name  ... compound  comp_score
# 0    837362634005454848          nayupoy  ...   0.0000     Neutral
# 1             576167561      untriplesix  ...   0.0000     Neutral
# 2             518715968  NBCSportsSoccer  ...   0.3400    Positive
# 3   1261979991224565760       cityscoop_  ...   0.0000     Neutral
# 4             266251364    lazqetjohnson  ...   0.6369    Positive
# 5              52102899           D_Lusk  ...   0.0000     Neutral
# 6             518715968  NBCSportsSoccer  ...   0.0000     Neutral
# 7             276233686      RyanDHobart  ...  -0.2500    Negative
# 8            2360551094       cashthib68  ...   0.3400    Positive
# 9    781870022293618688           GR_pod  ...   0.4588    Positive
# 10            161413417      colinblouin  ...   0.5106    Positive
# 11           1257180002           tax_i_  ...   0.0000     Neutral
# 12             24518986      littlejason  ...   0.0000     Neutral
# 13  1016579178290794497        JJJJIMMYY  ...   0.8402    Positive
# 14            338670340         rkc3indy  ...   0.0000     Neutral
#
# [15 rows x 13 columns]

# %% [markdown]
# Si crea una funzione che attribuisce la supposta appartenenza del tweet ad una tifoseria basandosi sugli hashtag citati e sulla neutralità o meno del tweet.

# %%
def tifoso(row):
  compound = row['compound'] 
  riga = row['compl_hashtags']
  if  ([row['comp_score'] =='Neutral']) and (('ManCity' in riga) or ('ManchesterCity' in riga)  or ('mcfc' in riga) or ('MCFC' in riga)) and (('PremierLeague' in riga) or ('pl' in riga) or ('PL' in riga) or ('TOTMCI' in riga)) and (('COYS' in riga) or ('thfc' in riga) or ('THFC' in riga) or ('spurs' in riga) or ('Spurs' in riga) or ('Tottenham' in riga)):
    if (compound>=-0.05 ) & (compound<=0.05):
      return "Neutral"
    else:
      return 'Tottenham'
  else:
    return 'Tottenham'

# %%
df_T_clean['tifo'] = df_T_clean.apply(tifoso, axis=1)
df_T_clean.head(15)
# Out:
#                 user_id      screen_name  ... comp_score       tifo
# 0    837362634005454848          nayupoy  ...    Neutral    Neutral
# 1             576167561      untriplesix  ...    Neutral  Tottenham
# 2             518715968  NBCSportsSoccer  ...   Positive  Tottenham
# 3   1261979991224565760       cityscoop_  ...    Neutral  Tottenham
# 4             266251364    lazqetjohnson  ...   Positive  Tottenham
# 5              52102899           D_Lusk  ...    Neutral    Neutral
# 6             518715968  NBCSportsSoccer  ...    Neutral    Neutral
# 7             276233686      RyanDHobart  ...   Negative  Tottenham
# 8            2360551094       cashthib68  ...   Positive  Tottenham
# 9    781870022293618688           GR_pod  ...   Positive  Tottenham
# 10            161413417      colinblouin  ...   Positive  Tottenham
# 11           1257180002           tax_i_  ...    Neutral  Tottenham
# 12             24518986      littlejason  ...    Neutral  Tottenham
# 13  1016579178290794497        JJJJIMMYY  ...   Positive  Tottenham
# 14            338670340         rkc3indy  ...    Neutral  Tottenham
#
# [15 rows x 14 columns]

# %% [markdown]
# Infine, si binarizzano le label sul sentiment per facilitare il processing successivo.

# %%
def Neut_bin(label):
  if label == "Neutral":
    return 1
  else:
    return 0

def Pos_bin(label):
  if label == "Positive":
    return 1
  else:
    return 0

def Neg_bin(label):
  if label == "Negative":
    return 1
  else:
    return 0

# %%
df_T_clean["Positive"] = df_T_clean["comp_score"].apply(Pos_bin)
df_T_clean["Negative"] = df_T_clean["comp_score"].apply(Neg_bin)
df_T_clean["Neutral"] = df_T_clean["comp_score"].apply(Neut_bin)

df_T_clean.head(15)
# Out:
#                 user_id      screen_name  ... Negative  Neutral
# 0    837362634005454848          nayupoy  ...        0        1
# 1             576167561      untriplesix  ...        0        1
# 2             518715968  NBCSportsSoccer  ...        0        0
# 3   1261979991224565760       cityscoop_  ...        0        1
# 4             266251364    lazqetjohnson  ...        0        0
# 5              52102899           D_Lusk  ...        0        1
# 6             518715968  NBCSportsSoccer  ...        0        1
# 7             276233686      RyanDHobart  ...        1        0
# 8            2360551094       cashthib68  ...        0        0
# 9    781870022293618688           GR_pod  ...        0        0
# 10            161413417      colinblouin  ...        0        0
# 11           1257180002           tax_i_  ...        0        1
# 12             24518986      littlejason  ...        0        1
# 13  1016579178290794497        JJJJIMMYY  ...        0        0
# 14            338670340         rkc3indy  ...        0        1
#
# [15 rows x 17 columns]

# %% [markdown]
# Si conservano solamente le colonne d'interesse

# %%
df_final = df_T_clean.drop('scores', axis = 1)
df_final.head(15)
# Out:
#                 user_id      screen_name  ... Negative  Neutral
# 0    837362634005454848          nayupoy  ...        0        1
# 1             576167561      untriplesix  ...        0        1
# 2             518715968  NBCSportsSoccer  ...        0        0
# 3   1261979991224565760       cityscoop_  ...        0        1
# 4             266251364    lazqetjohnson  ...        0        0
# 5              52102899           D_Lusk  ...        0        1
# 6             518715968  NBCSportsSoccer  ...        0        1
# 7             276233686      RyanDHobart  ...        1        0
# 8            2360551094       cashthib68  ...        0        0
# 9    781870022293618688           GR_pod  ...        0        0
# 10            161413417      colinblouin  ...        0        0
# 11           1257180002           tax_i_  ...        0        1
# 12             24518986      littlejason  ...        0        1
# 13  1016579178290794497        JJJJIMMYY  ...        0        0
# 14            338670340         rkc3indy  ...        0        1
#
# [15 rows x 16 columns]

# %%
df_final.to_csv("Spurs_clean.csv")
